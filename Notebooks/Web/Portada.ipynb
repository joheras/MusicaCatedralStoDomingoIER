# %% [markdown]
# <a href="https://colab.research.google.com/github/joheras/MusicaCatedralStoDomingoIER/blob/main/Notebooks/Web/Portada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
proporciones = (228,990)

# %%
port.shape
# Out:
# (2000, 5520, 3)

# %%
img = cv2.imread('portada.tif')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
fig, ax = plt.subplots(1,1,figsize=(16,16))
ax.imshow(img,cmap=plt.cm.binary)
ax.xaxis.set_ticklabels([])
ax.yaxis.set_ticklabels([])
plt.show()

# %%
img.shape
# Out:
# (6070, 4299, 3)

# %%
ins = img[2550:4550,1000:3960]
fig, ax = plt.subplots(1,1,figsize=(16,16))
ax.imshow(ins,cmap=plt.cm.binary)
ax.xaxis.set_ticklabels([])
ax.yaxis.set_ticklabels([])
plt.show()

# %%
tit = img[550:2550,730:3820]
fig, ax = plt.subplots(1,1,figsize=(16,16))
ax.imshow(tit,cmap=plt.cm.binary)
ax.xaxis.set_ticklabels([])
ax.yaxis.set_ticklabels([])
plt.show()

# %%
port = np.concatenate([tit,ins],axis=1)
fig, ax = plt.subplots(1,1,figsize=(16,16))
ax.imshow(port,cmap=plt.cm.binary)
ax.xaxis.set_ticklabels([])
ax.yaxis.set_ticklabels([])
plt.show()

# %%
port = img = cv2.cvtColor(port,cv2.COLOR_RGB2BGR)
cv2.imwrite('port.png',port)
# Out:
# True
