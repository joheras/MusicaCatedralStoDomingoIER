# %% [markdown]
# <a href="https://colab.research.google.com/github/joheras/MusicaCatedralStoDomingoIER/blob/main/Notebooks/SacarM%C3%BAsica/tf_deep_omr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # tf-deep-omr
# - https://github.com/OMR-Research/tf-end-to-end

# %% [markdown]
# ## Librerías

# %%
# %%capture
# !git clone https://github.com/OMR-Research/tf-end-to-end.git

# %%
# %%capture
# !wget https://grfia.dlsi.ua.es/primus/models/PrIMuS/Semantic-Model.zip
# !unzip Semantic-Model.zip

# %%
import cv2
from matplotlib import pyplot as plt

# %%
# %%capture
# !unzip dataset.zip

# %% [markdown]
# ## Predicción
# ### Hay que cambiar algunas lineas del archivo ctc_predict.py
#
# En concreto hay que borrar la línea 2 y poner:
#
# ```
# import tensorflow.compat.v1 as tf
# tf.disable_v2_behavior()
# ```

# %%
pent = cv2.imread('pent600.jpg')
fig, ax = plt.subplots(1,1,figsize=(16,16))
ax.imshow(pent)
plt.show()

# %%
# !python /content/tf-end-to-end/ctc_predict.py -image /content/pent600.jpg -model /content/semantic_model.meta -vocabulary /content/tf-end-to-end/Data/vocabulary_semantic.txt
# Out:
# 2021-04-30 07:28:18.326617: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# 2021-04-30 07:28:20.252466: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX512F
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-04-30 07:28:20.252667: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# ...

# %% [markdown]
# ## Evaluando manualmente en conjunto de test
# - Elegimos aleatiriamente unas cuantas

# %%
import os
from pathlib import Path

# %%
pent = cv2.imread('/content/dataset/train/images/pent600.jpg')
fig, ax = plt.subplots(1,1,figsize=(16,16))
a = !python '/content/tf-end-to-end/ctc_predict.py' -image '/content/dataset/train/images/pent600.jpg' -model '/content/semantic_model.meta' -vocabulary '/content/tf-end-to-end/Data/vocabulary_semantic.txt'
print(a[-1])
ax.imshow(pent)
plt.show()
# Out:
# ['clef-G2', 'keySignature-BbM', 'timeSignature-C/', 'rest-quarter', 'note-D3_quarter', 'note-D3_quarter', 'note-E3_quarter', 'barline', 'note-F3_quarter', 'note-E3_quarter', 'note-F3_quarter', 'note-G3_quarter', 'barline', 'note-A3_half', 'note-A3_quarter']

# %%
pent = cv2.imread('/content/dataset/test/images/pent101.jpg')
fig, ax = plt.subplots(1,1,figsize=(16,16))
a = !python '/content/tf-end-to-end/ctc_predict.py' -image '/content/dataset/test/images/pent101.jpg' -model '/content/semantic_model.meta' -vocabulary '/content/tf-end-to-end/Data/vocabulary_semantic.txt'
print(a[-1])
ax.imshow(pent)
plt.show()
# Out:
# ['clef-G2', 'timeSignature-C/', 'note-A4_whole', 'note-A4_double_whole', 'note-A4_double_whole', 'note-Bb4_whole', 'note-C5_half.', 'note-Bb4_quarter', 'note-A4_quarter', 'note-G4_quarter', 'note-A4_double_whole', 'rest-quadruple_whole']

# %%
pent = cv2.imread('/content/dataset/test/images/pent255.jpg')
fig, ax = plt.subplots(1,1,figsize=(16,16))
a = !python '/content/tf-end-to-end/ctc_predict.py' -image '/content/dataset/test/images/pent255.jpg' -model '/content/semantic_model.meta' -vocabulary '/content/tf-end-to-end/Data/vocabulary_semantic.txt'
print(a[-1])
ax.imshow(pent)
plt.show()
# Out:
# ['clef-G2', 'timeSignature-C/', 'note-B4_whole', 'note-F5_half.', 'note-G5_half', 'note-A5_half', 'note-A5_half', 'note-A5_whole', 'note-A5_half', 'note-G5_half.', 'note-F5_eighth', 'note-E5_half']

# %%
pent = cv2.imread('/content/dataset/test/images/pent403.jpg')
fig, ax = plt.subplots(1,1,figsize=(16,16))
a = !python '/content/tf-end-to-end/ctc_predict.py' -image '/content/dataset/test/images/pent403.jpg' -model '/content/semantic_model.meta' -vocabulary '/content/tf-end-to-end/Data/vocabulary_semantic.txt'
print(a[-1])
ax.imshow(pent)
plt.show()
# Out:
# ['clef-C1', 'keySignature-FM', 'timeSignature-C/', 'note-E5_quarter', 'note-E5_eighth', 'rest-whole', 'rest-whole', 'barline', 'note-G5_eighth', 'note-G5_eighth', 'note-G5_eighth', 'barline']

# %%
pent = cv2.imread('/content/dataset/test/images/pent384.jpg')
fig, ax = plt.subplots(1,1,figsize=(16,16))
a = !python '/content/tf-end-to-end/ctc_predict.py' -image '/content/dataset/test/images/pent384.jpg' -model '/content/semantic_model.meta' -vocabulary '/content/tf-end-to-end/Data/vocabulary_semantic.txt'
print(a[-1])
ax.imshow(pent)
plt.show()
# Out:
# ['clef-G2', 'keySignature-BbM', 'timeSignature-C/', 'rest-half', 'note-G5_quarter', 'note-F#5_half', 'note-D5_quarter', 'note-D6_quarter', 'barline', 'note-G5_quarter', 'note-A5_eighth', 'note-G5_eighth', 'note-G5_quarter.', 'note-F#5_eighth', 'barline', 'note-G5_quarter']

# %%
pent = cv2.imread('/content/dataset/test/images/pent508.jpg')
fig, ax = plt.subplots(1,1,figsize=(16,16))
a = !python '/content/tf-end-to-end/ctc_predict.py' -image '/content/dataset/test/images/pent508.jpg' -model '/content/semantic_model.meta' -vocabulary '/content/tf-end-to-end/Data/vocabulary_semantic.txt'
print(a[-1])
ax.imshow(pent)
plt.show()
# Out:
# ['clef-C1', 'keySignature-BbM', 'timeSignature-6/4', 'rest-eighth', 'barline', 'rest-quarter', 'rest-quarter', 'note-F5_eighth', 'barline', 'note-Bb4_eighth.', 'note-C5_sixteenth', 'note-Bb4_eighth', 'note-Ab5_quarter', 'note-F5_eighth', 'barline', 'note-F5_quarter', 'note-C5_quarter', 'rest-half', 'rest-eighth', 'note-F4_eighth', 'barline']

# %%
pent = cv2.imread('/content/dataset/test/images/pent97.jpg')
fig, ax = plt.subplots(1,1,figsize=(16,16))
a = !python '/content/tf-end-to-end/ctc_predict.py' -image '/content/dataset/test/images/pent97.jpg' -model '/content/semantic_model.meta' -vocabulary '/content/tf-end-to-end/Data/vocabulary_semantic.txt'
print(a[-1])
ax.imshow(pent)
plt.show()
# Out:
# ['clef-C1', 'timeSignature-C/', 'note-G4_whole.', 'note-A4_half', 'note-G4_quarter.', 'note-E4_quarter', 'note-F#4_half', 'note-G4_half', 'note-G4_half', 'note-G4_quadruple_whole', 'note-F#4_half', 'note-G4_whole']

# %%
pent = cv2.imread('/content/dataset/test/images/pent510.jpg')
fig, ax = plt.subplots(1,1,figsize=(16,16))
a = !python '/content/tf-end-to-end/ctc_predict.py' -image '/content/dataset/test/images/pent510.jpg' -model '/content/semantic_model.meta' -vocabulary '/content/tf-end-to-end/Data/vocabulary_semantic.txt'
print(a[-1])
ax.imshow(pent)
plt.show()
# Out:
# ['clef-C1', 'timeSignature-C/', 'timeSignature-3/2', 'multirest-4', 'rest-eighth', 'barline', 'note-F5_eighth.', 'note-G4_eighth', 'note-G4_eighth', 'note-G4_eighth', 'barline', 'note-G4_eighth.', 'note-C5_eighth.', 'note-D5_sixteenth', 'note-A4_quarter', 'rest-quarter', 'barline', 'note-D5_quarter.', 'note-D4_quarter']

# %%
pent = cv2.imread('/content/dataset/test/images/pent441.jpg')
fig, ax = plt.subplots(1,1,figsize=(16,16))
a = !python '/content/tf-end-to-end/ctc_predict.py' -image '/content/dataset/test/images/pent441.jpg' -model '/content/semantic_model.meta' -vocabulary '/content/tf-end-to-end/Data/vocabulary_semantic.txt'
print(a[-1])
ax.imshow(pent)
plt.show()
# Out:
# ['clef-C1', 'timeSignature-C/', 'note-G4_half', 'note-B4_half', 'barline', 'note-A4_eighth', 'note-B4_eighth', 'note-A4_eighth', 'note-B4_eighth', 'note-C5_quarter', 'note-B4_eighth', 'note-A4_eighth', 'barline', 'note-B4_quarter', 'rest-quadruple_whole']

# %%
pent = cv2.imread('/content/dataset/test/images/pent68.jpg')
fig, ax = plt.subplots(1,1,figsize=(16,16))
a = !python '/content/tf-end-to-end/ctc_predict.py' -image '/content/dataset/test/images/pent68.jpg' -model '/content/semantic_model.meta' -vocabulary '/content/tf-end-to-end/Data/vocabulary_semantic.txt'
print(a[-1])
ax.imshow(pent)
plt.show()
# Out:
# ['clef-G2', 'keySignature-FM', 'timeSignature-C/', 'barline', 'note-D5_half', 'note-G4_half', 'note-D5_whole', 'note-E5_half', 'note-B4_half', 'note-C5_double_whole.']

# %%
pent = cv2.imread('/content/dataset/train/images/pent1172.jpg')
fig, ax = plt.subplots(1,1,figsize=(16,16))
a = !python '/content/tf-end-to-end/ctc_predict.py' -image '/content/dataset/train/images/pent1172.jpg' -model '/content/semantic_model.meta' -vocabulary '/content/tf-end-to-end/Data/vocabulary_semantic.txt'
print(a[-1])
ax.imshow(pent)
plt.show()
# Out:
# ['clef-C1', 'timeSignature-C/', 'rest-eighth.', 'clef-F4', 'note-Bb4_quarter', 'note-G4_eighth.', 'rest-quarter', 'note-Bb4_quarter', 'note-A4_quarter', 'barline', 'note-A4_half', 'note-Bb4_quarter', 'rest-quarter', 'barline']

# %%
pent = cv2.imread('/content/pent2300.jpg')
fig, ax = plt.subplots(1,1,figsize=(16,16))
a = !python '/content/tf-end-to-end/ctc_predict.py' -image '/content/pent2300.jpg' -model '/content/semantic_model.meta' -vocabulary '/content/tf-end-to-end/Data/vocabulary_semantic.txt'
print(a[-1])
ax.axis('off')
ax.xaxis.set_ticklabels([])
ax.yaxis.set_ticklabels([])
ax.imshow(pent)
plt.show()
# Out:
# ['clef-G2', 'keySignature-BbM', 'timeSignature-3/2', 'note-A4_quarter', 'note-Bb4_eighth', 'barline', 'note-C5_eighth', 'note-Bb4_eighth', 'note-A4_eighth', 'barline', 'note-A4_eighth.', 'barline', 'note-G#4_half', 'note-C5_double_whole.', 'barline']

# %% [markdown]
# # Predicción de una obra completa

# %%
def pentagrama_Blanco(foto): 
  foto2 = foto.copy()
  gray = cv2.cvtColor(foto,cv2.COLOR_RGB2GRAY)
  (T,threshInv) = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
  dilate = cv2.dilate(threshInv.copy(),(15,1))
  
  for i in range(0,4):
    dilate = cv2.dilate(dilate,(15,1))

  cnts,_ = cv2.findContours(dilate.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

  for c in cnts:
    area = cv2.contourArea(c)
    if(area > 10000):
      #cv2.drawContours(foto2, [c], -1, (119, 90, 17), 2)
      (x, y, w, h) = cv2.boundingRect(c) # Mejor sacar el rectángulo contenido
      cv2.rectangle(foto2, (x, y), (x + w, y + h), (255,255,255), -1)
  return foto2

def borrar_texto(foto): 
  foto2 = foto.copy()
  foto = pentagrama_Blanco(foto)
  gray = cv2.cvtColor(foto,cv2.COLOR_RGB2GRAY)
  (T,threshInv) = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
  rectKernel=cv2.getStructuringElement(cv2.MORPH_RECT,(15,15))
  dilate=cv2.morphologyEx(threshInv,cv2.MORPH_CLOSE,rectKernel)
  cnts,_ = cv2.findContours(dilate.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
  for c in cnts:
    area = cv2.contourArea(c)
    if(area > 100):
      (x, y, w, h) = cv2.boundingRect(c) # Mejor sacar el rectángulo contenido
      cv2.rectangle(foto2, (x, y-3), (x + w, y + h+3), (255,255,255), -1)
  return foto2

# %%
def pentagramas(foto): 
  foto2 = foto.copy()
  foto = borrar_texto(foto)
  gray = cv2.cvtColor(foto,cv2.COLOR_RGB2GRAY)
  (T,threshInv) = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)
  dilate = cv2.dilate(threshInv.copy(),(15,1))
  
  for i in range(0,10):
    dilate = cv2.dilate(dilate,(15,1))

  cnts,_ = cv2.findContours(dilate.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
  k=1
  for c in cnts:
    area = cv2.contourArea(c)
    if(area > 10000):
      #cv2.drawContours(foto2, [c], -1, (119, 90, 17), 2)
      (x, y, w, h) = cv2.boundingRect(c) # Mejor sacar el rectángulo contenido
      cv2.imwrite('pents/pent'+str(k)+'.jpg',foto[y-15:y+102,x-15:x+911])
      k+=1

# %%
img = cv2.imread('obra804.jpg')
fig, ax = plt.subplots(1,1,figsize=(12,12))
ax.imshow(img)
plt.show()

# %%
pentagramas(img)
fig, ax = plt.subplots(3,1,figsize=(16,16))
pent = cv2.imread('pents/pent1.jpg')
ax[0].imshow(pent)
pent = cv2.imread('pents/pent2.jpg')
ax[1].imshow(pent)
pent = cv2.imread('pents/pent3.jpg')
ax[2].imshow(pent)
plt.show()

# %%
pent = cv2.imread('pents/pent1.jpg')
fig, ax = plt.subplots(1,1,figsize=(16,16))
a1 = !python '/content/tf-end-to-end/ctc_predict.py' -image '/content/pents/pent1.jpg' -model '/content/semantic_model.meta' -vocabulary '/content/tf-end-to-end/Data/vocabulary_semantic.txt'
a1 = [n for n in a1[6:-1] if n!='\t']
print(a1)
ax.imshow(pent)
plt.show()

pent = cv2.imread('pents/pent2.jpg')
fig, ax = plt.subplots(1,1,figsize=(16,16))
a2 = !python '/content/tf-end-to-end/ctc_predict.py' -image '/content/pents/pent2.jpg' -model '/content/semantic_model.meta' -vocabulary '/content/tf-end-to-end/Data/vocabulary_semantic.txt'
a2 = [n for n in a2[6:-1] if n!='\t']
print(a2)
ax.imshow(pent)
plt.show()

pent = cv2.imread('pents/pent3.jpg')
fig, ax = plt.subplots(1,1,figsize=(16,16))
a3 = !python '/content/tf-end-to-end/ctc_predict.py' -image '/content/pents/pent3.jpg' -model '/content/semantic_model.meta' -vocabulary '/content/tf-end-to-end/Data/vocabulary_semantic.txt'
a3 = [n for n in a3[6:-1] if n!='\t']
print(a3)
ax.imshow(pent)
plt.show()
# Out:
# ['clef-C1', 'keySignature-BbM', 'timeSignature-C/', 'note-F5_quarter', 'note-F5_quarter', 'note-E5_quarter', 'barline', 'note-E5_quarter', 'note-D5_quarter', 'rest-quarter', 'barline', 'note-G5_eighth', 'note-F5_eighth', 'note-E5_eighth', 'note-D5_quarter']
# ['clef-C1', 'timeSignature-C/', 'rest-quarter', 'note-C5_quarter', 'note-C5_quarter', 'note-Eb5_quarter', 'barline', 'note-F5_quarter', 'note-C5_quarter', 'barline', 'note-C5_half', 'note-B4_quarter', 'barline', 'note-C5_half', 'rest-quarter', 'barline']
# ['clef-C1', 'timeSignature-C/', 'note-Eb5_half', 'note-G5_quarter', 'note-F5_quarter', 'barline', 'note-Eb5_half', 'note-Eb5_half', 'barline', 'note-Eb5_half', 'note-D5_half', 'barline', 'note-Eb5_half', 'rest-half']

# %% [markdown]
# ### A Partir de aquí se puede realizar una conversión de su notación a la nuestra, para así aprovechar los algoritmos que hemos definido y poder mostrar los resultados con este modelo.
